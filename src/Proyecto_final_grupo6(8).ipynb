# %% [markdown]
# # ⚡ Grupo 6 - UTEC 4Geeks BID 2022 ⚡
# # *PROYECTO FINAL*

# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Introduction

# %% [markdown]
# Stroke happens when the blood supply to part of the brain is cut off. Without blood, brain cells can be damaged or die. Fast access to treatment saves lives and improves recovery.
#
# There are many factors, including tobacco use, physical inactivity, unhealthy diet, harmful use of alcohol, atrial fibrillation, raised blood lipid levels, obesity, genetic disposition, stress and depression.
#
# Stroke has already reached epidemic proportions. 1 in 4 of us will have a stroke in our lifetime.
#
# Ref: https://www.world-stroke.org/
#
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Stroke, a cerebrovascular disease, is one of the major causes of death. It causes significant health and financial burdens for both patients and health care systems. One of the important risk factors for stroke is health-related behavior, which is becoming an increasingly important focus of prevention. Many machine learning models have been built to predict the risk of stroke or to automatically diagnose stroke, using predictors such as lifestyle factors or radiological imaging. (Alanazi EM, Abdou A, Luo J. Predicting Risk of Stroke From Lab Tests Using Machine Learning Algorithms: Development and Evaluation of Prediction Models.
#  (JMIR Form Res. 2021 Dec 2;5(12):e23440. doi: 10.2196/23440. PMID: 34860663; PMCID: PMC8686476.)

# %% [markdown]
# **In Uruguay**, stroke has a fundamental epidemiological importance: it is among the three leading causes of death at a general level and it is the leading cause of disability in adults. According to data published by the Commission for Cardiovascular Health, around 80 million people living in the world today have suffered a stroke and, consequently, more than 50 million survivors live with some type of permanent disability. Although life after a stroke is not the same in many cases, it is possible, with the right care and support, to continue with a good quality of life. CVAs are time-dependent, which means that it is essential to identify them as quickly as possible in order to establish the most appropriate treatment for the patient and prevent possible sequelae; they constitute one of the leading causes of disease burden worldwide and in Uruguay, measured in years of healthy life lost, an indicator that encompasses both mortality and disability caused by these diseases.
#
# According to the latest data from the Ministry of Public Health, from December 2019, during 2018, 1,732 people died from stroke and 2,125 people from cerebrovascular causes in general. (https://um.edu.uy/noticias/el-acv-es-una-enfermedad-con-alta-incidencia-en-uruguay-y-el-mundo)

# %% [markdown]
# **Models can predict risk with high accuracy while maintaining a reasonable false positive rate.**
#
# Stroke is the second leading cause of death worldwide. According to the World Health Organization [1], 5 million people worldwide suffer a stroke every year. Of these, one third die and another third are left permanently disabled. In the United States, someone has a stroke every 40 seconds and every four minutes, someone dies [2]. The aftermath is devastating, with victims experiencing a wide range of disabling symptoms including sudden paralysis, speech loss or blindness due to blood flow interruption in the brain [3]. The economic burden to the healthcare system in the United States amounts to about $34 billion per year in the US [4]. An additional $40 per year is spend on care for elderly stroke survivors [5].
#
# ([1]  Stroke, Cerebrovascular accident | Health topics – WHO EMRO
#
# [2] Heart Disease and Stroke Statistics2020 Update: A Report From the …
#
# [3] The science of stroke: Mechanisms in search of treatments
#
# [4] American Heart Association Statistics Committee and Stroke Statisti…
#
# [5] Care received by elderly US stroke survivors may be underestimated.)

# %% [markdown]
# **Problem Statement**
#
# Study the relationships of several variables and Stroke and  predict the stroke probability with best model and hypertuned parameters.
#
# *Our proyect  it's about make an aplication to screen healthy patients to know the degree of probability of suffering a stroke or not suffering it  to have more tools to design a personalized prevention plan for doctors.*

# %% [markdown]
# # ***** REVISAR si lo ponemos

# %% [markdown]
# * Hypothesis
#
# Does age has impact on strokes?
#
# Does body mass index and glucose levels in a person propel a stroke?
#
# * Assumption
#
# Smoking can induce Stroke, is it true?
#
# Have Heart Disease is prone to Stroke, is it true?
#
# Hypertensión could lead to Stroke, is it true?

# %% [markdown]
# ### Metadata
# - id: unique identifier
# - gender: "Male", "Female" or "Other"
# - age: age of the patient
# - hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
# - heart_disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
# - ever_married: "No" or "Yes"
# - work_type: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
# - Residence_type: "Rural" or "Urban"
# - avg_glucose_level: average glucose level in blood
# - bmi: body mass index
# - smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
# - stroke: 1 if the patient had a stroke or 0 if not

# %% [markdown]
# **Studying the data dictionary our first conclusions is:
# Contains some of the preconditions recognized worldwide as causes of the disease. Therar others tha we have no dates.**

# %%
# !pip install --upgrade pip
# !pip install pandas numpy seaborn plotly
# !pip install sklearn
# !pip install statsmodels
# !pip install imblearn
# !pip install pygal
# !pip install autoviz
# !pip install missingno
# !pip install pywaffle
# %matplotlib inline
# !pip install lightgbm
# Out:
# Requirement already satisfied: pip in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (22.2.2)
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.4.4)
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.23.2)
# Requirement already satisfied: seaborn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: plotly in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (5.10.0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: scipy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: sklearn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.9.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.23.2)
# Requirement already satisfied: statsmodels in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: packaging>=21.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pandas>=0.25 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: scipy>=1.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.23.2)
# Requirement already satisfied: patsy>=0.5.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2022.2.1)
# Requirement already satisfied: six in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: imblearn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from imblearn) (0.9.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.23.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: pygal in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: autoviz in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.1.43)
# Requirement already satisfied: seaborn>=0.11.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (0.11.2)
# Requirement already satisfied: emoji in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (2.0.0)
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.23.2)
# Requirement already satisfied: holoviews>=1.14.6 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.14.9)
# Requirement already satisfied: bokeh>=2.4.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (2.4.3)
# Requirement already satisfied: ipython in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (8.4.0)
# Requirement already satisfied: xlrd in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: panel~=0.12.6 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (0.12.7)
# Requirement already satisfied: fsspec>=0.8.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (2022.8.1)
# Requirement already satisfied: xgboost>=0.82 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: nltk in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (3.7)
# Requirement already satisfied: matplotlib>=3.3.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (3.5.3)
# Requirement already satisfied: wordcloud in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.8.2.2)
# Requirement already satisfied: textblob in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (0.17.1)
# Requirement already satisfied: scikit-learn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.1.2)
# Requirement already satisfied: jupyter in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.0.0)
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (1.4.4)
# Requirement already satisfied: hvplot>=0.7.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (0.8.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (4.3.0)
# Requirement already satisfied: pyamg in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (4.2.3)
# Requirement already satisfied: statsmodels in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: pillow>=7.1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from bokeh>=2.4.2->autoviz) (9.2.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from bokeh>=2.4.2->autoviz) (3.1.2)
# Requirement already satisfied: PyYAML>=3.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from bokeh>=2.4.2->autoviz) (6.0)
# Requirement already satisfied: packaging>=16.8 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from bokeh>=2.4.2->autoviz) (21.3)
# Requirement already satisfied: tornado>=5.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from bokeh>=2.4.2->autoviz) (6.2)
# Requirement already satisfied: param<2.0,>=1.9.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from holoviews>=1.14.6->autoviz) (1.12.2)
# Requirement already satisfied: colorcet in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from holoviews>=1.14.6->autoviz) (3.0.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from holoviews>=1.14.6->autoviz) (2.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.3.3->autoviz) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.3.3->autoviz) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.3.3->autoviz) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas->autoviz) (2022.2.1)
# Requirement already satisfied: tqdm>=4.48.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from panel~=0.12.6->autoviz) (4.64.0)
# Requirement already satisfied: bleach in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from panel~=0.12.6->autoviz) (5.0.1)
# Requirement already satisfied: pyct>=0.4.4 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from panel~=0.12.6->autoviz) (0.4.8)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from panel~=0.12.6->autoviz) (2.28.1)
# Requirement already satisfied: setuptools<61,>=42 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from panel~=0.12.6->autoviz) (60.10.0)
# Requirement already satisfied: markdown in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from panel~=0.12.6->autoviz) (3.4.1)
# Requirement already satisfied: scipy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn>=0.11.1->autoviz) (1.9.1)
# Requirement already satisfied: traitlets>=5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (5.3.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (3.0.30)
# Requirement already satisfied: stack-data in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (0.3.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (2.12.0)
# Requirement already satisfied: decorator in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: pickleshare in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (0.18.1)
# Requirement already satisfied: backcall in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython->autoviz) (4.8.0)
# Requirement already satisfied: jupyter-console in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter->autoviz) (6.4.4)
# Requirement already satisfied: qtconsole in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter->autoviz) (5.3.2)
# Requirement already satisfied: notebook in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter->autoviz) (6.4.12)
# Requirement already satisfied: nbconvert in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter->autoviz) (6.5.0)
# Requirement already satisfied: ipywidgets in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter->autoviz) (8.0.1)
# Requirement already satisfied: ipykernel in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter->autoviz) (6.15.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nltk->autoviz) (2022.8.17)
# Requirement already satisfied: joblib in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nltk->autoviz) (1.1.0)
# Requirement already satisfied: click in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nltk->autoviz) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->autoviz) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels->autoviz) (0.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.1.1)
# Requirement already satisfied: six in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pexpect>4.3->ipython->autoviz) (0.7.0)
# Requirement already satisfied: wcwidth in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: webencodings in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: psutil in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel->jupyter->autoviz) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel->jupyter->autoviz) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel->jupyter->autoviz) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel->jupyter->autoviz) (1.6.2)
# Requirement already satisfied: nest-asyncio in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel->jupyter->autoviz) (1.5.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviz) (4.0.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviz) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from markdown->panel~=0.12.6->autoviz) (4.12.0)
# Requirement already satisfied: jupyterlab-pygments in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: nbformat>=5.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (5.4.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (0.6.6)
# Requirement already satisfied: tinycss2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (1.1.1)
# Requirement already satisfied: jupyter-core>=4.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: defusedxml in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: ipython-genutils in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from notebook->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from notebook->jupyter->autoviz) (0.15.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from notebook->jupyter->autoviz) (0.14.1)
# Requirement already satisfied: argon2-cffi in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: qtpy>=2.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from qtconsole->jupyter->autoviz) (2.2.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->panel~=0.12.6->autoviz) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->panel~=0.12.6->autoviz) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->panel~=0.12.6->autoviz) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->panel~=0.12.6->autoviz) (3.3)
# Requirement already satisfied: asttokens in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from stack-data->ipython->autoviz) (2.0.5)
# Requirement already satisfied: executing in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from stack-data->ipython->autoviz) (0.9.0)
# Requirement already satisfied: pure-eval in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->panel~=0.12.6->autoviz) (3.8.1)
# Requirement already satisfied: fastjsonschema in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (2.16.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (4.7.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.2.post1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (5.9.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.1)
# Requirement already satisfied: pycparser in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Requirement already satisfied: missingno in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: scipy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from missingno) (1.9.1)
# Requirement already satisfied: matplotlib in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from missingno) (3.5.3)
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from missingno) (1.23.2)
# Requirement already satisfied: seaborn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from missingno) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->missingno) (4.37.1)
# Requirement already satisfied: pandas>=0.23 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.23->seaborn->missingno) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pywaffle in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: matplotlib in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pywaffle) (3.5.3)
# Requirement already satisfied: fontawesomefree in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pywaffle) (6.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib->pywaffle) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# Requirement already satisfied: lightgbm in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (3.3.2)
# Requirement already satisfied: wheel in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from lightgbm) (1.23.2)
# Requirement already satisfied: scipy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from lightgbm) (1.9.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from lightgbm) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)

# %% [markdown]
# ## Step 0 Import Libraries and modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OrdinalEncoder 
from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

from sklearn.model_selection import GridSearchCV

from imblearn.under_sampling import NearMiss
from collections import Counter

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import  AdaBoostClassifier, ExtraTreesClassifier

import missingno as msno
import scipy.stats as stats
import warnings 
warnings.filterwarnings('ignore')
sns.set(style='darkgrid', context='notebook')

import re
import string
import time

#visulaization modules
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

#from pywaffle import Waffle
init_notebook_mode(connected= True)


#Common model helpers
from sklearn.preprocessing import (StandardScaler,
                                   LabelEncoder,
                                   OneHotEncoder)
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, 
                             auc, 
                             precision_score,
                             recall_score,
                             f1_score, 
                             roc_auc_score,
                             confusion_matrix)
from sklearn.model_selection import (GridSearchCV,
                                     StratifiedKFold,
                                     cross_val_score)


# dimensionality reduction
from sklearn.decomposition import PCA

import pylab as pl

# imbalance dataset handling

from imblearn.datasets import make_imbalance
from imblearn.under_sampling import (RandomUnderSampler, 
                                     ClusterCentroids,
                                     TomekLinks,
                                     NeighbourhoodCleaningRule,
                                     EditedNearestNeighbours,
                                     NearMiss)


from imblearn.over_sampling import (SMOTE,
                                    ADASYN)




# model algorithams
from sklearn.ensemble import (RandomForestClassifier, 
                              AdaBoostClassifier, 
                              GradientBoostingClassifier)
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Step 1. Load the dataset
# The information was downloaded from the Kaggle site.
#  https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset because we did not find Uruguayan public data about stroke.

# %%
df_raw = pd.read_csv('../data/raw/healthcare-dataset-stroke-data.csv')

# %%
#usamos este en el drive compartido
#df_raw = pd.read_csv('/content/drive/MyDrive/4geeks/Proyecto/colab/Copia de healthcare-dataset-stroke-data.csv')

# %%
#usamos este en el drive compartido
#df_raw = pd.read_csv('/content/drive/MyDrive/4geeks/Proyecto/colab/healthcare-dataset-stroke-data.csv')

# %% [markdown]
# ## 1.1 Get basic info

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# ## Initial Insights About Dataset
#
# - We have 12 columns with 5110 observations.
# - There are  categorical and numerical features.
#
#     Categorical Features: gender, ever_married, work_type, Residence_type, smoking_status
#
#     Binary Numerical Features: hypertension,heart_disease, stroke
#
#     Continous Numerical Features: age, avg_glucose_level, bmi
#
# - Missing value in bmi.

# %% [markdown]
# ## 1.2 Take a sample

# %%
df_raw.sample(10)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 2919  65473    Male  23.0             0              0           No
# 1316  45048  Female  21.0             0              0           No
# 2242  13380    Male  14.0             0              0           No
# 4360  46517  Female  66.0             0              1          Yes
# 4902  65333  Female  31.0             0              0          Yes
# 3983   7638  Female  51.0             0              0          Yes
# 847   49949    Male  44.0             0              0          Yes
# 3345  45701  Female  72.0             0              1           No
# 3634  69370    Male  78.0             0              0          Yes
# 1774  57109  Female  12.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 2919        Private          Urban              61.96  22.0           smokes
# 1316        Private          Urban             134.45  29.1     never smoked
# 2242       children          Urban             111.27  23.2          Unknown
# 4360        Private          Rural             196.58  41.9  formerly smoked
# 4902        Private          Rural              96.03  24.1          Unknown
# 3983        Private          Urban              95.70  24.8  formerly smoked
# 847         Private          Urban              58.47  24.4     never smoked
# 3345  Self-employed          Rural             124.38  23.4  formerly smoked
# 3634       Govt_job          Urban              59.74  27.0  formerly smoked
# 1774       children          Rural              81.66  23.5  formerly smoked
#
#       stroke
# 2919       0
# 1316       0
# 2242       0
# 4360       0
# 4902       0
# 3983       0
# 847        0
# 3345       0
# 3634       0
# 1774       0

# %% [markdown]
# ## 1.3 Transform if needed

# %% [markdown]
# In this dataset, there are 3 numerical attributes, age, average glucose level and bmi. Let’s normalize them to ensure that they have equal weightage when building a classifier. Noted that new columns were created rather than replacing the initial columns. This preserved the original data.

# %%
#set age as int
df_raw['age']=df_raw['age'].astype(int)

# Encoding the 'Sex' column
df_raw['gender'] = df_raw['gender'].map({'Male': 0, 'Female' : 1, 'Other': 2})
df_raw['gender'].astype(int)

# Encoding the 'Residence_type' column
df_raw['Residence_type'] = df_raw['Residence_type'].map({'Urban': 0, 'Rural' : 1})
df_raw['Residence_type'].astype(int)

# Encoding the 'smoking status' column
df_raw['smoking_status'] = df_raw['smoking_status'].map({'Unknown': 0, 'never smoked' : 1, 'smokes': 2 , 'formerly smoked':3})
df_raw['smoking_status'].astype(int)

# Encoding the 'ever_married' column
df_raw['ever_married'] = df_raw['ever_married'].apply(lambda x: 1 if x == 'Yes' else 0)

# Encoding the 'work_type' column
df_raw['work_type'] = df_raw['work_type'].map({'Private' : 0, 'Self-employed': 1, 'children': 2 , 'Govt_job':3, 'Never_worked':4})

# %% [markdown]
# ## Step 2. Make a basic EDA

# %% [markdown]
# **Studie duplicates**

# %%
df_duplicates = df_raw['id'].duplicated().sum()

print("Theres is not duplicated observation")
# Out:
# Theres is not duplicated observation

# %%
df_raw.isnull().sum().to_frame(name="Missing values").sort_values(by="Missing values", ascending=False).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_48af5_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_48af5_row1_col0, #T_48af5_row2_col0, #T_48af5_row3_col0, #T_48af5_row4_col0, #T_48af5_row5_col0, #T_48af5_row6_col0, #T_48af5_row7_col0, #T_48af5_row8_col0, #T_48af5_row9_col0, #T_48af5_row10_col0, #T_48af5_row11_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_48af5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48af5_level0_col0" class="col_heading level0 col0" >Missing values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48af5_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_48af5_row0_col0" class="data row0 col0" >201</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row1" class="row_heading level0 row1" >id</th>
#       <td id="T_48af5_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row2" class="row_heading level0 row2" >gender</th>
#       <td id="T_48af5_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_48af5_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row4" class="row_heading level0 row4" >hypertension</th>
#       <td id="T_48af5_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row5" class="row_heading level0 row5" >heart_disease</th>
#       <td id="T_48af5_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row6" class="row_heading level0 row6" >ever_married</th>
#       <td id="T_48af5_row6_col0" class="data row6 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row7" class="row_heading level0 row7" >work_type</th>
#       <td id="T_48af5_row7_col0" class="data row7 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row8" class="row_heading level0 row8" >Residence_type</th>
#       <td id="T_48af5_row8_col0" class="data row8 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row9" class="row_heading level0 row9" >avg_glucose_level</th>
#       <td id="T_48af5_row9_col0" class="data row9 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row10" class="row_heading level0 row10" >smoking_status</th>
#       <td id="T_48af5_row10_col0" class="data row10 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_48af5_level0_row11" class="row_heading level0 row11" >stroke</th>
#       <td id="T_48af5_row11_col0" class="data row11 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_raw.describe()
# Out:
#                  id       gender          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354     0.586301    43.215264      0.097456       0.054012
# std    21161.721625     0.492941    22.633866      0.296607       0.226063
# min       67.000000     0.000000     0.000000      0.000000       0.000000
# 25%    17741.250000     0.000000    25.000000      0.000000       0.000000
# 50%    36932.000000     1.000000    45.000000      0.000000       0.000000
# 75%    54682.000000     1.000000    61.000000      0.000000       0.000000
# max    72940.000000     2.000000    82.000000      1.000000       1.000000
#
#        ever_married    work_type  Residence_type  avg_glucose_level  \
# count   5110.000000  5110.000000     5110.000000        5110.000000
# mean       0.656164     0.832094        0.491977         106.147677
# std        0.475034     1.109924        0.499985          45.283560
# min        0.000000     0.000000        0.000000          55.120000
# 25%        0.000000     0.000000        0.000000          77.245000
# 50%        1.000000     0.000000        0.000000          91.885000
# 75%        1.000000     2.000000        1.000000         114.090000
# max        1.000000     4.000000        1.000000         271.740000
#
#                bmi  smoking_status       stroke
# count  4909.000000     5110.000000  5110.000000
# mean     28.893237        1.198630     0.048728
# std       7.854067        1.053603     0.215320
# min      10.300000        0.000000     0.000000
# 25%      23.500000        0.000000     0.000000
# 50%      28.100000        1.000000     0.000000
# 75%      33.100000        2.000000     0.000000
# max      97.600000        3.000000     1.000000

# %% [markdown]
# **2.1 Get basic info**

# %% [markdown]
# **2.2 Describe the numerical and date variables**

# %% [markdown]
# **2.3 Describe the categorical variables**

# %% [markdown]
# **2.4 Perform univariate analysis - histograms**

# %% [markdown]
# **2.5 Perform univariate analysis - boxplots**

# %% [markdown]
# **2.6 Perform bivariate analysis - scatter matrix**

# %% [markdown]
#  **2.7 Perform correlation analysis - Pearson or Point Biserial**

# %% [markdown]
# Correlation coefficient
#
# The correlation coefficient is a statistical measure of the strength of the relationship between the relative movements of two variables.
# The values range between -1.0 and 1.0.
#
# * A calculated number greater than 1.0 or less than -1.0 means that there was an error in the correlation measurement.
# * A correlation of -1.0 shows a perfect negative correlation, while a correlation of 1.0 shows a perfect positive correlation.
# * A correlation of 0.0 shows no linear relationship between the movement of the two variables.

# %%
#Plotting a heatmap to find relations between features

plt.figure(figsize=(12, 8))
sns.heatmap(df_raw.corr(), annot=True,cmap='viridis', vmax=1, vmin=-1, center=0)

# %% [markdown]
# ## Falta interpretar la correlación

# %% [markdown]
# **2.8 Perform multivariate analysis - VIF**

# %% [markdown]
# **2.9 Split the dataset so to avoid bias**

# %%
#we define our labels and features
y = df_raw['stroke']
X = df_raw.drop('stroke', axis=1)
#we divide into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=13,stratify=y)

# %% [markdown]
#  **2.10 Join the train sets to ease insights**

# %% [markdown]
#  **2.11 Take a sample**

# %% [markdown]
# ## Step 3. Create and evaluate model - Define your approach and goals

# %% [markdown]
# **3.1 Perform model fit - A**

# %% [markdown]
# **3.2 Perform model fit - B**

# %% [markdown]
# **3.3 Calculate metrics on model A**

# %% [markdown]
#  **3.4 Calculate metrics on model B**

# %% [markdown]
# ## Step 4. Write up your conclusions
